# %% [markdown]
# # Alunos:
#
# ### Carlos Eduardo Fontaneli

# %%
import pandas as pd
from efficient_apriori import apriori

# %% [markdown]
# ## Importando métodos e bibliotecas necessárias
#
# - `Pandas` para leitura dos dados e formatação deles como dataframes;
# - `apriori` algoritmo de regras de associação;

# %% [markdown]
# ## Lendo os dados
#
# Dados relativos a um modelo desenvolvido para avaliar aplicações de estudantes para escolas de enfermagem. Dessa forma, o conjunto de dados possui 8 atributos e uma classse, a qual será desconsiderada para a aplicação do algoritmo de regras de associação. Os dados foram lidos de um arquivo com extensão `.csv` para o formate `dataframe`.

# %%
data = pd.read_csv("nursery_data.csv", header = None, names = ['parents', 'has_nurs', 'form', 'children', 'housing', 'finance', 'social', 'health', 'class']) # fonte http://archive.ics.uci.edu/ml/datasets/Nursery

data.head()
# Out:
#   parents has_nurs      form children     housing     finance         social  \
# 0   usual   proper  complete        1  convenient  convenient        nonprob
# 1   usual   proper  complete        1  convenient  convenient        nonprob
# 2   usual   proper  complete        1  convenient  convenient        nonprob
# 3   usual   proper  complete        1  convenient  convenient  slightly_prob
# 4   usual   proper  complete        1  convenient  convenient  slightly_prob
#
#         health      class
# 0  recommended  recommend
# 1     priority   priority
# 2    not_recom  not_recom
# 3  recommended  recommend
# 4     priority   priority

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12960 entries, 0 to 12959
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   parents   12960 non-null  object
#  1   has_nurs  12960 non-null  object
#  2   form      12960 non-null  object
#  3   children  12960 non-null  object
#  4   housing   12960 non-null  object
#  5   finance   12960 non-null  object
#  6   social    12960 non-null  object
#  7   health    12960 non-null  object
#  8   class     12960 non-null  object
# dtypes: object(9)
# memory usage: 911.4+ KB

# %% [markdown]
# ## Processamento dos dados
#
# Para aplicar o algoritmo `apriori` é necessário transformar os dados em listas de tuplas. Assim sendo, acessa-se cada linha do `dataframe`, iterando sobre todas as colunas, exceto a última que é relatica a classe, colocando-se cada elemento numa lista que será adicionada no final a outra lista. Ademais, a coluna de classe é ignorada, pois o algoritmo não busca fazer uma classifição dos dados e sim extrair possíveis regras de associação.

# %%
t_list = []

for i in range(len(data)):
  l_in = []
  for j in range(8):
    s = str(data.values[i, j])
    if (s != 'nan'): # ignora casos onde não há dados
      l_in.append(s)
  t_list.append(l_in)
  
t_list
# Out:
# [['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   '3',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'complete',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   '3',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'completed',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'incomplete',
#   '1',
#   'convenient',
# ...
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'proper',
#   'foster',
#   'more',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '1',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'less_conv',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '2',
#   'critical',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'convenient',
#   'inconv',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'nonprob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'slightly_prob',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'recommended'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'priority'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'convenient',
#   'problematic',
#   'not_recom'],
#  ['usual',
#   'less_proper',
#   'complete',
#   '3',
#   'less_conv',
#   'inconv',
#   'nonprob',
#   'recommended'],
#  ...]

# %% [markdown]
# ## Execução do algoritmo apriori
#
# Aqui extra-se os itemset e conjunto de regras possíveis de se encontrar nos dados. O suporte e a confiança mínimas foram configuradas para 20%, porque foram realizados testes progressivos e com esse valor o algoritmo é capaz de encontrar um número satisfatória de itemsets e regras para o conjunto de dados em questão.

# %%
itemsets, rules = apriori(t_list, min_support=0.2, min_confidence=0.2)

# %%
# Itemsets encontrados
itemsets
# Out:
# {1: {('usual',): 4320,
#   ('proper',): 2592,
#   ('complete',): 3240,
#   ('1',): 3240,
#   ('convenient',): 8640,
#   ('nonprob',): 4320,
#   ('recommended',): 4320,
#   ('priority',): 4320,
#   ('not_recom',): 4320,
#   ('slightly_prob',): 4320,
#   ('problematic',): 4320,
#   ('inconv',): 6480,
#   ('less_conv',): 4320,
#   ('critical',): 6048,
#   ('2',): 3240,
#   ('3',): 3240,
#   ('more',): 3240,
#   ('completed',): 3240,
#   ('incomplete',): 3240,
#   ('foster',): 3240,
#   ('less_proper',): 2592,
#   ('improper',): 2592,
#   ('very_crit',): 2592,
#   ('pretentious',): 4320,
#   ('great_pret',): 4320},
#  2: {('convenient', 'critical'): 3456,
#   ('convenient', 'great_pret'): 2880,
#   ('convenient', 'nonprob'): 2880,
#   ('convenient', 'not_recom'): 2880,
#   ('convenient', 'pretentious'): 2880,
#   ('convenient', 'priority'): 2880,
#   ('convenient', 'problematic'): 2880,
#   ('convenient', 'recommended'): 2880,
#   ('convenient', 'slightly_prob'): 2880,
#   ('convenient', 'usual'): 2880,
#   ('critical', 'inconv'): 3024}}

# %%
# Regras encontradas
rules
# Out:
# [{critical} -> {convenient},
#  {convenient} -> {critical},
#  {great_pret} -> {convenient},
#  {convenient} -> {great_pret},
#  {nonprob} -> {convenient},
#  {convenient} -> {nonprob},
#  {not_recom} -> {convenient},
#  {convenient} -> {not_recom},
#  {pretentious} -> {convenient},
#  {convenient} -> {pretentious},
#  {priority} -> {convenient},
#  {convenient} -> {priority},
#  {problematic} -> {convenient},
#  {convenient} -> {problematic},
#  {recommended} -> {convenient},
#  {convenient} -> {recommended},
#  {slightly_prob} -> {convenient},
#  {convenient} -> {slightly_prob},
#  {usual} -> {convenient},
#  {convenient} -> {usual},
#  {inconv} -> {critical},
#  {critical} -> {inconv}]

# %% [markdown]
# ## Métricas das regras
#
# A seguir apresenta-se as métricas de suporte, confiança, lift e convicção de cada regra encontrada.

# %%
for rule in rules:
  print(rule)
# Out:
# {critical} -> {convenient} (conf: 0.571, supp: 0.267, lift: 0.857, conv: 0.778)
# {convenient} -> {critical} (conf: 0.400, supp: 0.267, lift: 0.857, conv: 0.889)
# {great_pret} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {great_pret} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {nonprob} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {nonprob} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {not_recom} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {not_recom} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {pretentious} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {pretentious} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {priority} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {priority} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {problematic} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {problematic} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {recommended} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {recommended} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {slightly_prob} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {slightly_prob} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {usual} -> {convenient} (conf: 0.667, supp: 0.222, lift: 1.000, conv: 1.000)
# {convenient} -> {usual} (conf: 0.333, supp: 0.222, lift: 1.000, conv: 1.000)
# {inconv} -> {critical} (conf: 0.467, supp: 0.233, lift: 1.000, conv: 1.000)
# {critical} -> {inconv} (conf: 0.500, supp: 0.233, lift: 1.000, conv: 1.000)

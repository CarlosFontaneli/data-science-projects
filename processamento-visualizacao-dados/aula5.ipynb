# %%
import pandas as pd

df = pd.read_csv('Data/diabetes.csv')

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import numpy as np

a = pd.Series([0, 1, np.nan, 3, 4, 5, 6, 7, np.nan])

b = a.interpolate()

# %%
import matplotlib.pyplot as plt

plt.plot(b)
plt.plot(a)
plt.show()

# %%
a = pd.Series([0, 1, np.nan, 3, 4, 5, 6, 7, np.nan, 9, np.nan, 45])

b = a.interpolate(method='polynomial', order=2)

plt.plot(b)
plt.plot(a)
plt.show()

# %%
df.replace(0, np.NaN, inplace=True)

df.interpolate(method='linear', limit_direction='backward')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0     94.0  33.6
# 1            1.0     85.0           66.0           29.0     94.0  26.6
# 2            8.0    183.0           64.0           26.0     94.0  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            3.0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0    146.0  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0           27.0      NaN  30.1
# 767          1.0     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50      1.0
# ...

# %%
simple_random_sample = df.sample(n=5, random_state=42)
simple_random_sample
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 668          6.0     98.0           58.0           33.0    190.0  34.0
# 324          2.0    112.0           75.0           32.0      NaN  35.7
# 624          2.0    108.0           64.0            NaN      NaN  30.8
# 690          8.0    107.0           80.0            NaN      NaN  24.6
# 473          7.0    136.0           90.0            NaN      NaN  29.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 668                     0.430   43      NaN
# 324                     0.148   21      NaN
# 624                     0.158   21      NaN
# 690                     0.856   34      NaN
# 473                     0.210   50      NaN

# %%
idx = np.arange(0, len(df), step=5)
systematic_sample = df.iloc[idx]
systematic_sample
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      NaN  33.6
# 5            5.0    116.0           74.0            NaN      NaN  25.6
# 10           4.0    110.0           92.0            NaN      NaN  37.6
# 15           7.0    100.0            NaN            NaN      NaN  30.0
# 20           3.0    126.0           88.0           41.0    235.0  39.3
# ..           ...      ...            ...            ...      ...   ...
# 745         12.0    100.0           84.0           33.0    105.0  30.0
# 750          4.0    136.0           70.0            NaN      NaN  31.2
# 755          1.0    128.0           88.0           39.0    110.0  36.5
# 760          2.0     88.0           58.0           26.0     16.0  28.4
# 765          5.0    121.0           72.0           23.0    112.0  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50      1.0
# ...

# %%
from imblearn.over_sampling import SMOTE
from sklearn.datasets import load_breast_cancer

df = load_breast_cancer()

X = pd.DataFrame(df.data, columns=df.feature_names)
y = df.target

# %%
smote = SMOTE(random_state=0)

X_resample, y_resample = smote.fit_resample(X, y)

X_resample = pd.DataFrame(X_resample, X_resample.columns)

X_resample
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                      NaN           NaN             NaN        NaN
# mean texture                     NaN           NaN             NaN        NaN
# mean perimeter                   NaN           NaN             NaN        NaN
# mean area                        NaN           NaN             NaN        NaN
# mean smoothness                  NaN           NaN             NaN        NaN
# mean compactness                 NaN           NaN             NaN        NaN
# mean concavity                   NaN           NaN             NaN        NaN
# mean concave points              NaN           NaN             NaN        NaN
# mean symmetry                    NaN           NaN             NaN        NaN
# mean fractal dimension           NaN           NaN             NaN        NaN
# radius error                     NaN           NaN             NaN        NaN
# ...

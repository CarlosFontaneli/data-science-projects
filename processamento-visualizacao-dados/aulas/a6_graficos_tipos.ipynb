# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../data/shampoo.csv")
df.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %% [markdown]
# ### Gráfico de linhas

# %%
_ = df.plot(kind='line',x='Month',y='Sales',color='blue')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pylab import *
t = arange(0.0, 2.0, 0.01)
s = sin(2.5*pi*t)
plot(t, s)
xlabel('time (s)')
ylabel('voltage (mV)')
title('Sine Wave')
grid(True)
show()

# %%
x=np.arange(10)

plt.plot(x,x*1,c='b',marker="^",ls='--',label='Linear',fillstyle='none')
plt.plot(x, x**2,c='g',marker=(8,2,0),ls='--',label='*2')
plt.plot(x,x**3,c='k',ls='-',label='*3')
plt.title("Taxa de Crescimento de tempo dos algoritmos.")
plt.xlabel("n")
plt.ylabel("Tempo de execucao (segundos)")
plt.legend(loc=2)
plt.show()

# %%
x=np.linspace(0, 12, 10000)

plt.plot(x,x*1,c='b',ls='-',label='Linear',fillstyle='none')
plt.plot(x, x**2,c='g',ls='-',label='Quadrática')
plt.plot(x,x**3,c='k',ls='--',label='Cúbica')
plt.plot(x,2**x,c='r',ls='--',label='Exponencial')
plt.title("Taxa de Crescimento de tempo dos algoritmos.")
plt.xlabel("n")
plt.ylabel("Tempo de execucao (segundos)")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ### Gráfico de Barras

# %%
itens = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']

performance = [10,8,6,4,2,1]

plt.bar(itens, performance)

plt.ylabel('Uso')

plt.title('Uso de linguagem de programação')

plt.show()

# %%
import plotly.express as px

dadosbrasil = px.data.gapminder().query("country == 'Brazil'")

fig = px.bar(dadosbrasil, x='year', y='pop')

fig.show()
